# %% [markdown]
# ###### In this project we have two datasets ie. Flipkart and Amazon in which we are going to merge our data and extract the particular columns according to our requirements.

# %% [markdown]
# ### Import the libraries

# %%
import pandas as pd

# %%
amazon = pd.read_csv(r'C:\Users\hp\Desktop\amz_com-ecommerce_sample.csv')
flipkart = pd.read_csv(r'C:\Users\hp\Desktop\flipkart_com-ecommerce_sample.csv')

# %%
amazon.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
# to check the shape of the data
amazon.shape
# Out:
# (20000, 15)

# %%
# to check the columns name in amazon data
amazon.columns
# Out:
# Index(['uniq_id', 'crawl_timestamp', 'product_url', 'product_name',
#        'product_category_tree', 'pid', 'retail_price', 'discounted_price',
#        'image', 'is_FK_Advantage_product', 'description', 'product_rating',
#        'overall_rating', 'brand', 'product_specifications'],
#       dtype='object')

# %% [markdown]
# #### Renaming the columns name of amazon

# %%
amazon.rename(columns={'product_name':'Product name in Amazon','retail_price':'Retail Price in Amazon','discounted_price':'Discounted Price in Amazon'}, inplace=True)

# %%
# To fetch the top 5 records of flipkart data
flipkart.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
# to check the columns name in flipkart data
flipkart.columns
# Out:
# Index(['uniq_id', 'crawl_timestamp', 'product_url', 'product_name',
#        'product_category_tree', 'pid', 'retail_price', 'discounted_price',
#        'image', 'is_FK_Advantage_product', 'description', 'product_rating',
#        'overall_rating', 'brand', 'product_specifications'],
#       dtype='object')

# %%
#flipkart.isna().sum()

# %% [markdown]
# #### Renaming the columns name of flipkart

# %%
flipkart.rename(columns={'product_name':'Product name in Flipkart','retail_price':'Retail Price in Flipkart','discounted_price':'Discounted Price in Flipkart'}, inplace=True)

# %% [markdown]
# #### Merge the both dataframes on "uniq_id"

# %%
df = pd.merge(amazon,flipkart, on='uniq_id')

# %%
df.shape
# Out:
# (20000, 29)

# %%
df.head()
# Out:
#                             uniq_id          crawl_timestamp_x  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                        product_url_x  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                   Product name in Amazon  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
df.isna().sum()
# Out:
# uniq_id                            0
# crawl_timestamp_x                  0
# product_url_x                      0
# Product name in Amazon             0
# product_category_tree_x            0
# pid_x                              0
# Retail Price in Amazon             0
# Discounted Price in Amazon         0
# image_x                            3
# is_FK_Advantage_product_x          0
# description_x                      2
# product_rating_x                   0
# overall_rating_x                   0
# brand_x                         5864
# product_specifications_x          14
# crawl_timestamp_y                  0
# product_url_y                      0
# Product name in Flipkart           0
# product_category_tree_y            0
# pid_y                              0
# Retail Price in Flipkart          78
# Discounted Price in Flipkart      78
# image_y                            3
# is_FK_Advantage_product_y          0
# description_y                      2
# ...

# %% [markdown]
# #### To fetch the particular columns from the data according to our need.

# %%
df = df[['Product name in Amazon','Retail Price in Amazon','Discounted Price in Amazon','Product name in Flipkart','Retail Price in Flipkart','Discounted Price in Flipkart']]

# %%
df.isna().sum()
# Out:
# Product name in Amazon           0
# Retail Price in Amazon           0
# Discounted Price in Amazon       0
# Product name in Flipkart         0
# Retail Price in Flipkart        78
# Discounted Price in Flipkart    78
# dtype: int64

# %% [markdown]
# #### There is 78 null values in "Retail Price in Flipkart" and "Discounted Price in Flipkart".

# %%
# So we are going to fill the null values with "0" because I don't want to loose the data 
df = df.fillna(0)

# %%
df
# Out:
#                         Product name in Amazon  Retail Price in Amazon  \
# 0          Alisha Solid Women's Cycling Shorts                     982
# 1          FabHomeDecor Fabric Double Sofa Bed                   32143
# 2                                   AW Bellies                     991
# 3          Alisha Solid Women's Cycling Shorts                     694
# 4        Sicons All Purpose Arnica Dog Shampoo                     208
# ...                                        ...                     ...
# 19995           WALLDESIGN SMALL VINYL STICKER                    1498
# 19996  WALLMANTRA LARGE VINYL STICKERS STICKER                    1415
# 19997  ELITE COLLECTION MEDIUM ACRYLIC STICKER                    1284
# 19998  ELITE COLLECTION MEDIUM ACRYLIC STICKER                    1492
# 19999  ELITE COLLECTION MEDIUM ACRYLIC STICKER                    1484
#
#        Discounted Price in Amazon                 Product name in Flipkart  \
# ...
